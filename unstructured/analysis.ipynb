# %%
import json

# %%
with open('../data/nchs-leading-causes-of-death-united-states.json', 'r') as f:
    death_dict = json.load(f)

# %%
death_dict
# Out:
# [{'Year': 2012,
#   '113 Cause Name': 'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)',
#   'Cause Name': 'Kidney disease',
#   'State': 'Vermont',
#   'Deaths': 21,
#   'Age-adjusted Death Rate': 2.6},
#  {'Year': 2017,
#   '113 Cause Name': 'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)',
#   'Cause Name': 'Kidney disease',
#   'State': 'Vermont',
#   'Deaths': 29,
#   'Age-adjusted Death Rate': 3.3},
#  {'Year': 2016,
#   '113 Cause Name': 'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)',
#   'Cause Name': 'Kidney disease',
#   'State': 'Vermont',
#   'Deaths': 30,
#   'Age-adjusted Death Rate': 3.7},
#  {'Year': 2013,
#   '113 Cause Name': 'Nephritis, nephrotic syndrome and nephrosis (N00-N07,N17-N19,N25-N27)',
#   'Cause Name': 'Kidney disease',
#   'State': 'Vermont',
#   'Deaths': 30,
#   'Age-adjusted Death Rate': 3.8},
#  {'Year': 2000,
# ...
